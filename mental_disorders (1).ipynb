# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

md=pd.read_csv("mental_disorders_dataset (2).csv")

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3a78e651-10fe-48b9-a5dd-b274a6fd41ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3a78e651-10fe-48b9-a5dd-b274a6fd41ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
md=pd.read_csv("mental_disorders_dataset (2).csv")
md
# Out:
#     Patient Number     Sadness    Euphoric  Exhausted Sleep dissorder  \
# 0       Patiant-01     Usually      Seldom  Sometimes       Sometimes
# 1       Patiant-02     Usually      Seldom    Usually       Sometimes
# 2       Patiant-03   Sometimes  Most-Often  Sometimes       Sometimes
# 3       Patiant-04     Usually      Seldom    Usually      Most-Often
# 4       Patiant-05     Usually     Usually  Sometimes       Sometimes
# ..             ...         ...         ...        ...             ...
# 115    Patiant-116  Most-Often      Seldom    Usually       Sometimes
# 116    Patiant-117   Sometimes   Sometimes  Sometimes          Seldom
# 117    Patiant-118     Usually   Sometimes    Usually       Sometimes
# 118    Patiant-119     Usually   Sometimes     Seldom          Seldom
# 119    Patiant-120   Sometimes     Usually     Seldom         Usually
#
#     Mood Swing Suicidal thoughts Anorxia Authority Respect Try-Explanation  \
# ...

# %%
md.head()
# Out:
#   Patient Number    Sadness    Euphoric  Exhausted Sleep dissorder Mood Swing  \
# 0     Patiant-01    Usually      Seldom  Sometimes       Sometimes        YES
# 1     Patiant-02    Usually      Seldom    Usually       Sometimes         NO
# 2     Patiant-03  Sometimes  Most-Often  Sometimes       Sometimes        YES
# 3     Patiant-04    Usually      Seldom    Usually      Most-Often        YES
# 4     Patiant-05    Usually     Usually  Sometimes       Sometimes         NO
#
#   Suicidal thoughts Anorxia Authority Respect Try-Explanation  \
# 0              YES       NO                NO             YES
# 1               YES      NO                NO              NO
# 2                NO      NO                NO             YES
# 3               YES     YES                NO             YES
# 4                NO      NO                NO              NO
#
#   Aggressive Response Ignore & Move-On Nervous Break-down Admit Mistakes  \
# ...

# %%
md.isnull().sum()
# Out:
# Patient Number         0
# Sadness                0
# Euphoric               0
# Exhausted              0
# Sleep dissorder        0
# Mood Swing             0
# Suicidal thoughts      0
# Anorxia                0
# Authority Respect      0
# Try-Explanation        0
# Aggressive Response    0
# Ignore & Move-On       0
# Nervous Break-down     0
# Admit Mistakes         0
# Overthinking           0
# Sexual Activity        0
# Concentration          0
# Optimisim              0
# Expert Diagnose        0
# dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=md, x='Expert Diagnose', palette='coolwarm')
plt.title("diagnosis distribution")
plt.xlabel("Expert Diagnose")
plt.ylabel("count")
plt.show()
# Out:
# /tmp/ipython-input-890804831.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=md, x='Expert Diagnose', palette='coolwarm')

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=md, x='Mood Swing',hue='Expert Diagnose', palette='viridis')
plt.title("Mood Swing vs Expert Diagnose")
plt.show()

# %%
size=(plt.figure(fig6,4))
sns.countplot(data=md, x='Suicidal thoughts',hue='Expert Diagnose', palette='muted')
plt.title("Suicidal Thoughts by diagnosis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=md, x='Sleep dissorder',hue='Expert Diagnose', palette='viridis')
plt.title("Sleep dissorder vs Expert Diagnose")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=md, x='Sadness',hue='Expert Diagnose', palette='viridis')
plt.title("Sadness vs Expert Diagnose")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=md, x='Euphoric',hue='Expert Diagnose', palette='muted')
plt.title("Euphoric by diagnosis")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=md, x='Exhausted',hue='Expert Diagnose', palette='viridis')
plt.title("Exhausted vs Expert Diagnose")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=md, x='Anorxia',hue='Expert Diagnose', palette='viridis')
plt.title("Anorxia vs Expert Diagnose")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=md, x='Authority Respect',hue='Expert Diagnose', palette='viridis')
plt.title("Authority Respect vs Expert Diagnose")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=md, x='Try-Explanation',hue='Expert Diagnose', palette='viridis')
plt.title("Try-Explanation vs Expert Diagnose")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=md, x='Aggressive Response',hue='Expert Diagnose', palette='viridis')
plt.title("Aggressive Response vs Expert Diagnose")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=md, x='Ignore & Move-On',hue='Expert Diagnose', palette='viridis')
plt.title("Ignore & Move-On vs Expert Diagnose")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=md, x='Nervous Break-down',hue='Expert Diagnose', palette='viridis')
plt.title("Nervous Break-down vs Expert Diagnose")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=md, x='Admit Mistakes',hue='Expert Diagnose', palette='viridis')
plt.title("Admit Mistakes vs Expert Diagnose")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=md, x='Overthinking',hue='Expert Diagnose', palette='viridis')
plt.title("Overthinking vs Expert Diagnose")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=md, x='Sexual Activity',hue='Expert Diagnose', palette='viridis')
plt.title("Sexual Activity vs Expert Diagnose")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=md, x='Concentration',hue='Expert Diagnose', palette='viridis')
plt.title("Concentration vs Expert Diagnose")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=md, x='Optimisim',hue='Expert Diagnose', palette='viridis')
plt.title("Optimisim vs Expert Diagnose")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=md, x='Expert Diagnose',hue='Expert Diagnose', palette='viridis')
plt.title("Expert Diagnose vs Expert Diagnose")
plt.show()
